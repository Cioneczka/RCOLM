# %%
import essentia.standard as es

# %%
def keyExtraction(file_path):

# %%
file_path = '/home/ciona/projects/RCOLM/data/raw_data/GTZAN/genres_original/blues/blues.00011.wav'

keyExtraction(file_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 file_path = '/home/ciona/projects/RCOLM/data/raw_data/GTZAN/genres_original/blues/blues.00011.wav'
# ----> 3 keyExtraction(file_path)
#
# Cell In[2], line 3, in keyExtraction(file_path)
#       1 def keyExtraction(file_path):
# ----> 3     print(essentia.KeyExtractor(file_path))
#
# AttributeError: module 'essentia' has no attribute 'KeyExtractor'
